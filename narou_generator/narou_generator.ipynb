# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import re
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN
from keras.callbacks import LambdaCallback

with open("get_narou_story.txt", mode = "r", encoding = "utf-8")as f:
    text_original = f.read()
    
text = re.sub("allcount[^}]+}", "", text_original)
text = re.sub("[【】{}()（）/※■◆◇★☆○●◎「」『』]", "", text)
text = re.sub("[nu&,:;'?=]", "", text)
text = re.sub("[［］\[\]]", "", text)
text = re.sub("[0-9a-zA-Z]{4,}", "", text)
text = re.sub(" 　", "", text)
text = re.sub(r'\\', "", text)

n_rnn = 10 #時系列の数
batch_size = 128
epochs = 60
n_mid = 128 #中間層のニューロン数

chars = sorted(list(set(text)))#setで文字の重複削除
print("文字数（重複なし）", len(chars))
char_indices = {}
for i, char in enumerate(chars):
    char_indices[char] = i
indices_char = {}
for i, char in enumerate(chars):
    indices_char[i] = char
    
time_chars = []
next_chars = []
for i in range(0,len(text) - n_rnn):
    time_chars.append(text[i: i + n_rnn])
    next_chars.append(text[i + n_rnn])
    
x = np.zeros((len(time_chars), n_rnn, len(chars)), dtype=np.bool)
t = np.zeros((len(time_chars), len(chars)), dtype=np.bool)
for i, t_cs in enumerate(time_chars):
    t[i, char_indices[next_chars[i]]] = 1
    for j, char in enumerate(t_cs):
        x[i, j, char_indices[char]] = 1
        
print("x", x.shape)
print("y", t.shape)

model = Sequential()
model.add(SimpleRNN(n_mid, input_shape=(n_rnn, len(chars))))
model.add(Dense(len(chars), activation="softmax"))
model.compile(loss='categorical_crossentropy', optimizer="adam")
print(model.summary())

def on_epoch_end(epoch, logs):
    print("エポック: ", epoch)

    beta = 5  # 確率分布を調整する定数
    prev_text = text[0:n_rnn]  # 入力に使う文字
    created_text = prev_text  # 生成されるテキスト
    
    print("シード: ", created_text)

    for i in range(400):
        # 入力をone-hot表現に
        x_pred = np.zeros((1, n_rnn, len(chars)))
        for j, char in enumerate(prev_text):
            x_pred[0, j, char_indices[char]] = 1
        
          # 予測を行い、次の文字を得る
        y = model.predict(x_pred)
        p_power = y[0] ** beta  # 確率分布の調整
        next_index = np.random.choice(len(p_power), p=p_power/np.sum(p_power))        
        next_char = indices_char[next_index]

        created_text += next_char
        prev_text = prev_text[1:] + next_char

    print(created_text)
    print()
    
epock_end_callback= LambdaCallback(on_epoch_end=on_epoch_end)

history = model.fit(x, t,
                    batch_size=batch_size,
                    epochs=epochs,
                    callbacks=[epock_end_callback])

loss = history.history['loss']
plt.plot(np.arange(len(loss)), loss)
plt.show()
# Out:
# 文字数（重複なし） 2298
# x (154101, 10, 2298)
# y (154101, 2298)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_4 (SimpleRNN)     (None, 128)               310656
# _________________________________________________________________
# dense_4 (Dense)              (None, 2298)              296442
# =================================================================
# Total params: 607,098
# Trainable params: 607,098
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:From /Users/chiakikato/anaconda3/envs/nlp_bot/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/60
# 154101/154101 [==============================] - 143s 927us/step - loss: 5.3786
# エポック:  0
# シード:    山田健一は３５歳
#   山田健一は３５歳の、そのなった。それた。そのは、それないた。そのは、それていた。そんは、それていた。そのないとしていた。そのは、そのなった。そのなった。そのないた。その世界に転生していた。そのは、それないます。
#
# Epoch 2/60
# 154101/154101 [==============================] - 140s 909us/step - loss: 4.3923
# エポック:  1
# シード:    山田健一は３５歳
#   山田健一は３５歳の物語。
#
# Epoch 3/60
# 154101/154101 [==============================] - 137s 889us/step - loss: 3.9231
# エポック:  2
# シード:    山田健一は３５歳
#   山田健一は３５歳ので、その世界に転生した。そのは、そのでも、そのは、魔法の世界に転生した。そのは、そのは、そのは、そのないという。そのは、そのは、神様になっていた。そんな彼は、その世界に転生した。そのは、人のでもない。そのは、その世界に転生した。そのは、そのは、そのは、人のの人を持った。そのは、神様のない、そのは、そんなります。
#
# Epoch 4/60
# 154101/154101 [==============================] - 136s 881us/step - loss: 3.6384
# エポック:  3
# シード:    山田健一は３５歳
#   山田健一は３５歳ので、そんな人生を歩んでいた。そんな彼は、その世界で、転生した。そのは、そのは、神様になっていた。
#
# Epoch 5/60
# 154101/154101 [==============================] - 143s 929us/step - loss: 3.4331
# エポック:  4
# シード:    山田健一は３５歳
#   山田健一は３５歳のできたいただけど、ある日、書籍化しました。  書籍化しました。
#
# Epoch 6/60
# 154101/154101 [==============================] - 136s 882us/step - loss: 3.2742
# エポック:  5
# シード:    山田健一は３５歳
#   山田健一は３５歳ので、そのは、人間になっていた。そんな彼は、ある日、あります。
#
# Epoch 7/60
# 154101/154101 [==============================] - 138s 893us/step - loss: 3.1417
# エポック:  6
# シード:    山田健一は３５歳
#   山田健一は３５歳の誕生日によろしくお願いします。  書籍版のまである日、あらもの物語である。それは、それはそれなら、その世界で生きることが出来るのからものだった。そんな彼は、その世界で、それは、これは、この世界で、そのは、自分の人の子供に生きていた。そこは、これは、この世界で、そのは、この世界で、そのは、魔物の世ので、ある日、ある日、そんなります。  異世界である。それは、これは、この世界で、そのは、この世界で、ある日本人のです。  ある日、ありません。  異世界で生きていく。そこでは、この世界で、そこは異世界であるからもない、そのは、ある日本人のである日、あったりのから、それは、神様になっていた。
#
# Epoch 8/60
# 154101/154101 [==============================] - 136s 883us/step - loss: 3.0310
# エポック:  7
# シード:    山田健一は３５歳
#   山田健一は３５歳になったり、その世界で、そのは、自分の知識を利用していた。しかし、お願いいただけで、なんなんだからないと思います。  ある日、ある日、あったりのから、それなので、その知識を生きることになった。そんない、転生した。そのは、自分の知識を活かしていくない。
#
# Epoch 9/60
# 154101/154101 [==============================] - 135s 873us/step - loss: 2.9345
# エポック:  8
# シード:    山田健一は３５歳
#   山田健一は３５歳になったが、異世界でのだった。それは、自分の人生を歩むことになった。それは、それなら、そのでも、いからものからも、いただけど、そんないただけど、そんなスキルを持っていた。そんな中で、そこは異世界で転生したら、そんなからものだった。
#
# Epoch 10/60
# 154101/154101 [==============================] - 139s 902us/step - loss: 2.8489
# エポック:  9
# シード:    山田健一は３５歳
#   山田健一は３５歳の誕生日によろしくお願いします。
#
# Epoch 11/60
# 154101/154101 [==============================] - 130s 845us/step - loss: 2.7709
# エポック:  10
# シード:    山田健一は３５歳
#   山田健一は３５歳になったが、彼は、神の知識を使って、異世界に転生した。その時代が、その時代の知識を使って、そのは、自分の知識を使い、それは、気づくと、国の世界を救うため、彼は、その時代の知識を使って、その願うやきない。そして、自分の知識を使ってもらいくもない。そして、自分の知識を使い、それは、自分の知識を使い、それは、人間の名前に生きるというので、そしてもられるのだが、そんな彼女の子の生活を送る為、そのは、異世界に転生した。そうにも人生を歩んでいた。
#
# Epoch 12/60
# 154101/154101 [==============================] - 140s 906us/step - loss: 2.7012
# エポック:  11
# シード:    山田健一は３５歳
#   山田健一は３５歳の誕生日に、そのは、自分の小説が、最強のスキルとして、そのでもなっていた。そんな彼は、その世界で生きることになった。そのでき、魔法の才能はそんなかった。そのなく、彼はそのは、やってそんな魔法は、そんなスキルとして生きた。そんな彼は、前世の記憶を持っていた。その知識を生きていた。それなの人生。そんな彼は、その世界で生きていた。しかし、人間の名前の知識を使って、スタートルをもごく普通の男性がらないと思います。  目の前には、自分の知識を使い、それは、神様からも、魔物としていた。そのなく、そんな彼は、その世界の生まれた。これは、その世界に転生したら、その世界で生きていく。そして、自分の体を持っていた。そのは、あるとなんだからない。そんな彼は、その世界で生きることになった。そのは、自分の力を持っていた。それは、自分の知識を使って、大陸の少女になって、まった。そんな彼女は、そのできたら、そんなことは
#
# Epoch 13/60
# 154101/154101 [==============================] - 139s 902us/step - loss: 2.6364
# エポック:  12
# シード:    山田健一は３５歳
#   山田健一は３５歳のサライトを変更しました。
#
# Epoch 14/60
# 154101/154101 [==============================] - 137s 889us/step - loss: 2.5793
# エポック:  13
# シード:    山田健一は３５歳
#   山田健一は３５歳のサラストーラストーランとして生まれ変わったいた。そのは、色々と人の子供を助けてるというもない。そのは、自分の体の世界に転生したら、その世界を救うことをしていた。
#
# Epoch 15/60
# 154101/154101 [==============================] - 132s 854us/step - loss: 2.5254
# エポック:  14
# シード:    山田健一は３５歳
#   山田健一は３５歳になったが、そして、自分の尻に、やることになっていた。そんな彼女の子は、その世界を救うことになる。それな彼は、この世界では、この世界を生き抜くことになってしまった。そして、自分の人生を歩むことになっていた。だが、それは平凡な人生を歩むことになってしまう。その思い、そのは、気が付けば背景キャラの異世界で、異世界に転生していた。しかし、彼女の前世の記憶を持つ少年が、人生を歩んでみたいた。その世界を救うことになる。  気が付いたらは、人間の名前を継ぐ力と、戦闘は無能ないかね！！本編完結済み。
#
# Epoch 16/60
# 154101/154101 [==============================] - 131s 847us/step - loss: 2.4765
# エポック:  15
# シード:    山田健一は３５歳
#   山田健一は３５歳でした。そんな中ではなく、そんな彼女はなっていた。しかし、彼は一度はそうと思います。  書籍化しました。
#
# Epoch 17/60
# 154101/154101 [==============================] - 131s 850us/step - loss: 2.4301
# エポック:  16
# シード:    山田健一は３５歳
#   山田健一は３５歳のサライトル変更しました。
#
# Epoch 18/60
# 154101/154101 [==============================] - 132s 854us/step - loss: 2.3865
# エポック:  17
# シード:    山田健一は３５歳
#   山田健一は３５歳童貞の男が、剣と魔法の世界に転生した。そうから俺はなんなか？
#
# Epoch 19/60
# 154101/154101 [==============================] - 132s 857us/step - loss: 2.3466
# エポック:  18
# シード:    山田健一は３５歳
#   山田健一は３５歳のサラリーマンが、次々と一緒になります。それは、自分の神のからせってくるようなく。それならばいいのだった。それは、人間には今日もらいくらない。それなら、魔力を使っていた。それは、自分の体の世界に転生したら、そのは、自分の神のからによっていた。前世の記憶を取り戻し、その度ことを思い、上になっていた。しかし、彼女の力を持つ男になってした。そのは、自分の体の世界に転生したら、そのは、自分の神のから創生の物語である。
#
# Epoch 20/60
# 154101/154101 [==============================] - 131s 849us/step - loss: 2.3076
# エポック:  19
# シード:    山田健一は３５歳
#   山田健一は３５歳のサラリーマンが、次々のかった。それは、自分の体の世界を救ったのは、その世界は、この世界で、魔法を使えるとして、異世界に転生していた。しかし、そこは世界を目指す、、この世界を救いたのは、その世界は、この世界で、魔法を使えず、誰ものかった。そしてもうわない……。
#
# Epoch 21/60
# 154101/154101 [==============================] - 131s 850us/step - loss: 2.2726
# エポック:  20
# シード:    山田健一は３５歳
#   山田健一は３５歳のサラリーマンだった。この世界は、この世界で、世界を司る女神から、世界の生まれた。  気がついたらには、自分の知識を活かしていくない。そこは、人間の名前の知識を使って成り上がっていく。そして、自分の生活を目指する。そこでは、王都への旅立されて、投稿しています。
#
# Epoch 22/60
# 154101/154101 [==============================] - 131s 851us/step - loss: 2.2368
# エポック:  21
# シード:    山田健一は３５歳
#   山田健一は３５歳のサラリーマンだが、なんだからもいいついで、俺はなくてもりとして生まれていた。そんな彼の異世界に転生した。そこは、人間になっていた。それは、人間の一人の少女を助ける。そして異世界で転生した。そのは、自由に生きることを知る。そして、自分の体を持つ少年の生涯を終えた。しかし、前世の記憶を持っていた。その後、皇宮のイケモノに変わった世界で、人間が怯えて暮らし、モンスターになると、突然、魔法が使えるから、それての気づくと、白植世界に強制限を駆け巡る。
#
# Epoch 23/60
# 154101/154101 [==============================] - 132s 854us/step - loss: 2.2051
# エポック:  22
# シード:    山田健一は３５歳
#   山田健一は３５歳のクラストルスティタストルリスは、これは何故か夢だった。ちょっと、白虹の賢者に続きます。
#
# Epoch 24/60
# 154101/154101 [==============================] - 130s 843us/step - loss: 2.1737
# エポック:  23
# シード:    山田健一は３５歳
#   山田健一は３５歳のサラスキルを駆使して、自由に生きている世界に転生した。だが、そんな彼は、その世界を生き抜く為に複数の中では、気づいたらは、魔力ならも、自分の身体を取り戻ればからない。この世界は、この世界ではなくのかった。その世界は、この世界を目指してしまう。そして何がないから離れた能力を持っている。そのは、神の代の者がちょっとスタートルにもいうじゃない！！いかも、それからずれ、自分の際に巻き込まれ、幸せに暮らしている。そんな彼は、母親が麻薬に手を入れた結果、その世界を救うことになる。そして家族のこうになった。だった。そんな彼女はない、魔王になっていた。しかし、彼は瞑想の中である、イラストは無いな女神にもられることを知っていた。しかし、シナは、日本人にはって、剣と魔法のファンタジー世界に転生したことは知らない。そんな彼は、母親が麻薬に手を入れた結果、その世界を救うこの世界で生きていくの話。第一章：竜の代。
#
# Epoch 25/60
# 154101/154101 [==============================] - 128s 829us/step - loss: 2.1442
# エポック:  24
# シード:    山田健一は３５歳
#   山田健一は３５歳のサラリーマンタートラストは、転生した先は、彼は魔力を持っていることを思っています。  書籍化しました！    目の日に、カクヨムにも投稿しています。
#
# Epoch 26/60
# 154101/154101 [==============================] - 128s 832us/step - loss: 2.1157
# エポック:  25
# シード:    山田健一は３５歳
#   山田健一は３５歳のお兄とんでもない、神様の魔王になっていた。しかし、彼女の前世の記憶がある。その後の皇子にリったります。
#
# Epoch 27/60
# 154101/154101 [==============================] - 128s 830us/step - loss: 2.0872
# エポック:  26
# シード:    山田健一は３５歳
#   山田健一は３５歳のサラリーマングを構成出すが、これまでもごく普通の男が、周囲のは、世界に転生した。この世界で、ケルトとして、魔術の力を得た。そんなので、そう思い出す。これは、そんな彼女の子は、転生した。そこに生まれ変わった。弟子の人生を成ったが、彼は、その時を目覚めたと森に生まれたして。そんな彼に転生した先は、彼女の子は、それられる異世界に転生したら、そこと、気づくと、国生の世界に転生した。だった。だった俺は、妹と呼ばれることになった。そんな彼は生まれ変わった。弟子は、ただった。異世界に転生した。そこで、人生がられる。そこでは気づきた社畜生きたらした。現代日本で、若くりも無いないだけでもない。せんか？これは、何かか？何かもいいない。それは、これは、世界に転生した。だから、人生を歩んでいく。それは、運命を再び動きたいた。まったりだった。それは、自分の体の世界には、運命を察して。そして、自分の人間になっていた
#
# Epoch 28/60
# 154101/154101 [==============================] - 127s 822us/step - loss: 2.0617
# エポック:  27
# シード:    山田健一は３５歳
#   山田健一は３５歳のサラリーマングを構成、上がっていた。前世の知識とあったのだが、ある日もの存在しらもいくないう。だかませんなんだからも、助けることになった。そんな彼は、前世の記憶を持ち、きることを知る。
#
# Epoch 29/60
# 154101/154101 [==============================] - 128s 830us/step - loss: 2.0371
# エポック:  28
# シード:    山田健一は３５歳
#   山田健一は３５歳でしたい人は、小さな小説のはキャラファポリスでも公開始める。
#
# Epoch 30/60
# 154101/154101 [==============================] - 128s 829us/step - loss: 2.0112
# エポック:  29
# シード:    山田健一は３５歳
#   山田健一は３５歳でしていた。そんな彼女は、周りの人生を歩むことになっていた。そんな彼は生き残りことになってしまう。その思い出しまで死んだ。しかし、彼女は違えられるようにない、田中の際は、全てに困惑に落ちためる。その性格が、役割を求めるスキルを開始していた。
#
# Epoch 31/60
# 154101/154101 [==============================] - 128s 829us/step - loss: 1.9881
# エポック:  30
# シード:    山田健一は３５歳
#   山田健一は３５歳でした。小説のは素材でもないまで、作品などの作品はおわっちゃんはお話。＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊＊
#
# Epoch 32/60
# 154101/154101 [==============================] - 128s 830us/step - loss: 1.9649
# エポック:  31
# シード:    山田健一は３５歳
#   山田健一は３５歳のサラスキルも、そんなからかないまで、シリーズ内向かり認められる事になる。そのは、神の代の世界に転生した先は、そして異世界へと転生した。この世界は、この世界を堪っしたいき、スラインは魔王になる、魔物が仲間たちも、異世界の少女がちを倒れた男の身体ラックがつかり出し、そこでチート能力を選択した。その内際は日本である、それは運命を覆すせめてみるとなろうと思います。＊カクヨムにも投稿しています。
#
# Epoch 33/60
# 154101/154101 [==============================] - 129s 834us/step - loss: 1.9441
# エポック:  32
# シード:    山田健一は３５歳
#   山田健一は３５歳のサラリーマンチートの存在。  親が、帰宅できょう。注意：されにも投えないとしていく、その思いを力に望みを賭けながら、それは、ある程の強いなからない、何故かしてしくれたのは、僕は、奴隷に買えない。それでも、それは、自分の知識を活用していたいき、そこは何処か世界。そこはそれなかった。そんな異世界へと転生してしまった。そのは、僕の知識を利用してくしいう。そんな彼のからも、その悪魔とないの事になります。
#
# Epoch 34/60
# 154101/154101 [==============================] - 126s 818us/step - loss: 1.9206
# エポック:  33
# シード:    山田健一は３５歳
#   山田健一は３５歳のサラリーマングを構成功を起きることになる。これは、気付くて女神と呼ばれることになった。そんなことになる。これは世界では自由に生きている世界に転生した。その肉体は、体に動き出すことになった。そんな世界で、魔法を使っていく物語。この強盗賊少女の世界を拡大しているというだけど……。そんな世界で、魔物がいたら、世界できる事になっていた。そこは最強の魔術の扱いを頼りになってしまう。その思いをもねると喜んだかっていたのは、おっさんが、舌先三寸で未来を切り開く。悪魔物語です。  第五章：第１章一新、書籍化しました！ありがとうございます！  ある日、魔法の才能はそんな世界で、魔物やいていき、王都の物語は、学校から学生と残ってした世界は、正世界生活が始まり。転生していたらしか生き延びてしまった。  注意：この世界に転生したらした。その異世界生活を終わり、別の村から炎をするた。数し、私は、望みを隠して生き延
#
# Epoch 35/60
# 154101/154101 [==============================] - 126s 817us/step - loss: 1.8994
# エポック:  34
# シード:    山田健一は３５歳
#   山田健一は３５歳でしていたが、見れらぬ唯一の薬師ださい。一度目の前に現れたので、そんなどうなることが、それは、自分の体は、やらな日常を目指します。前世の記憶を持ったいたのだが、そんな彼女の力を持ってしまう。その時には、死んでしまう。そのは、日々の魔術を使って、自分の居場所を作っているのは、その世界で、彼の錬金術師として成功していく。  異世界の女は、そんな危険な魔法を使って、異世界に転生していた。した彼は、前世の記憶を持ち十一歳の中です。それは、国には魔王の美少女、成長してい生活屋をに届く、たの物理でのないともうっていた。しかも、彼は、何故から創ら魔法の王子として転生した先の街、そんな彼は、その世界の常識を遥かに凌駕するものだった──この世界は、こので前世の記憶を持っていることが決意した。だが、前世の記憶がありません。魔法の才能はある。それは、自分の体の世界を離れ、魔法がありません。  異世界でしたレベル
#
# Epoch 36/60
# 154101/154101 [==============================] - 126s 819us/step - loss: 1.8818
# エポック:  35
# シード:    山田健一は３５歳
#   山田健一は３５歳童貞美少女として、たらいいの領民拉鬼たらして巨乳児子の元かにこれられいことを思い出せた。その知識を生きて、高位少女に続けていた。しかし、魔力の類は手ない草でありますが苦手な方はご注意ください。  前世の記憶を取り戻した時にてるようになった。これは、この小説家は最強ギフルという名に、アルファポリス様にも掲載しています。  書籍化学三巻まで発売中。  書籍版第１巻が発売中です。  書籍化決定した。  アルトはあり、そんな危険な車に走る事もある。この小説は、他人と共に、第10人のからを開くてしてくるといな生活からおいいい。ゆっくりのみるというだった。そんな世界で幽閉されてもらっていた。人生前によって、魔物というない。魔王に強めて美味が、危険ないく物語。
#
# Epoch 37/60
# 154101/154101 [==============================] - 126s 817us/step - loss: 1.8617
# エポック:  36
# シード:    山田健一は３５歳
#   山田健一は３５歳のサラリーマンチートの神に選ばれておかけです。これます。
#
# Epoch 38/60
# 154101/154101 [==============================] - 125s 814us/step - loss: 1.8428
# エポック:  37
# シード:    山田健一は３５歳
#   山田健一は３５歳になった学院を科学技術理由になくらないった。いからせないただけ答通さになっている。さいこの世界に飛ばされた彼は、前世の記憶を持っていることを決意した。だが、それは神々の人を救わたが異世界に転生した。その時、自身は不老者。ち関わるべくスを切り掛けられ、幼馴染の女性士のゴリリー要素はある。  社畜の生涯を終えた。しかし、前世の記憶を思い出す。これは、そんな彼の生活を試していきた。サンジーマンチートの世界に転生していた。これは、自分の生涯を開くて、生活を送りために討伐を請っています。前作の事がとうごといます。  ある日ように命が入らせていた。ある日、天才魔術師姿をしてしまう。人々の世界観光でするための物語と、どうからもってもいうじめる。
#
# Epoch 39/60
# 154101/154101 [==============================] - 125s 813us/step - loss: 1.8248
# エポック:  38
# シード:    山田健一は３５歳
#   山田健一は３５歳の誕生日に就くことしてします。
#
# Epoch 40/60
# 154101/154101 [==============================] - 127s 825us/step - loss: 1.8060
# エポック:  39
# シード:    山田健一は３５歳
#   山田健一は３５歳のサラリーマングを構成、上がりという宝に残れな世界に転生した。転生先の異世界に転生した。これは、そころ辺境にＭＭノベルス様より、投稿しております。  書籍版１２月２８日、２０１９月５０日、累計ＰＶ４1話第二巻が発売中です。  書籍化ものままで読みてくます。  書籍化しました。２巻が発売予定です。詳しくは、母親の文字程の望むと謀ろうちと一緒に色々と手に入れる。その世界を楽しみがいていく。それは平和に過労でしたり、彼には、自由に転生した先は、そんな考えて、電子書籍化でする予定です。
#
# Epoch 41/60
# 154101/154101 [==============================] - 139s 901us/step - loss: 1.7877
# エポック:  40
# シード:    山田健一は３５歳
#   山田健一は３５歳童貞美少女トラッキング1位獲得。..はどうぜかったなく物語です。死んでしまった。しかし、元日本であると言うのであ。カクヨムにも投稿しています。   NEW!! .5.17金に、富士クラスが選ばれ、カード図せを魅力的なり、神様のであった。しかし、そんな舞踏火の屋に繁銀をしていたらしいう。だが、そんな矢理可でい。少女のだった。異世界の片田舎のパン屋で、文字がございませんと、一つの間によろしくお願いしたします。
#
# Epoch 42/60
# 154101/154101 [==============================] - 137s 888us/step - loss: 1.7722
# エポック:  41
# シード:    山田健一は３５歳
#   山田健一は３５歳のサラリーマングを構成、新たの森を受けた。その後をご覧にされる方とにより、魔物を育成りする。     気が付くと、白い世間に認めると、その神様を感激されたらには、ただと思います。作者の手によりになっていた。果たして彼は忍法は赤ん坊として転生した。そこでも心をしていくまでにご覧いために公が決意をする。そこは五歳はこの世界で、魔法を使ってもくった。それから気づきたらないった。そして、自分の生まれていることになった。その世界は、その世界を救うこの世界に転生した。そこで、人間がラックス生活を送ることになった。しかし、それは、自称の知識を使っていたが、魔王の襲い男が、馬車っていくだった。この世界は、世界の原作者の成り上がっていた。その知識を生かして生きていた。その時代は、彼女は弟が上げてほしんないた。そこは、人間を使い、幼馴染の能力を得てしまった。しから、そんな世界を降り立った世界。その目の前世では
#
# Epoch 43/60
# 154101/154101 [==============================] - 136s 880us/step - loss: 1.7559
# エポック:  42
# シード:    山田健一は３５歳
#   山田健一は３５歳のサラリーマングを構成功を起きることをしたしかし、彼は、導いていく物語の物語。  転生の子爵家の生まれた。――これは、経験値が当ていたださん。  結婚ばします。  突然、アニメ化版です。コミカライズ決定！
#
# Epoch 44/60
# 154101/154101 [==============================] - 154s 998us/step - loss: 1.7376
# エポック:  43
# シード:    山田健一は３５歳
#   山田健一は３５歳のクラスト化な物につ、新しく人生を歩み入っていた。しかし、人々の能力をかげてみたっという。しかし、それなかった。そんな徹はあった主人公。そんな中で、華がある？定期は、さん ちょも投稿していたコラックにより、トルーファンタジーです。コミカライズして中りす。絶望的に成長していた青年は、御王になりに入ってした。そして彼女の子達と、仲間たちの物語。ゆっくりがすることになった。それは、自分の生活を追加掛けられた異世界転生した。転生先の異世界に転生した。それから、爺さんので生まれたちと共に、クの側を継者になっている。  朝怖デレベル、上げ、トになられるかず、彼は、周りの国に頼りになっていい。加護を2ついたらと思い出す。これは、魔石な魔力を得てみたいない。そのない、スライムをすることになる。これは、生活の反動物語。       転生した先は、気楽しく旅をする。  書籍化します。  書籍化しました。  ノ
#
# Epoch 45/60
# 154101/154101 [==============================] - 139s 900us/step - loss: 1.7230
# エポック:  44
# シード:    山田健一は３５歳
#   山田健一は３５歳のサラリーマンだった。そして五年として心に――した死んだ社畜、自然の不思議な創生を歩みために異世界に転生した。そこでは、人間が怯えて暮らし、モンスターの戦争を参加した。負けに目覚めたときます。それは、自分の生前世でもったら異世界で、未来を持っていた。頼りになるようなった。そんな家族に囲まれてやる。  世界で、自由気ままたらに返したいただきます。
#
# Epoch 46/60
# 154101/154101 [==============================] - 138s 898us/step - loss: 1.7077
# エポック:  45
# シード:    山田健一は３５歳
#   山田健一は３５歳童貞美少女となっている。そこでは、主人公は、悪役のみたいう。だが、そんなかっていくのさんがゃんやっている。
#
# Epoch 47/60
# 154101/154101 [==============================] - 131s 850us/step - loss: 1.6924
# エポック:  46
# シード:    山田健一は３５歳
#   山田健一は３５歳のサラリーマンチートの革命譚。これは、意味をいたしまで、俺は気分なので、神器も収入ってんがあります。カクヨムにも掲載しております。  突然、RPGのは奮闘する中でも色々なくない人生を送る。……？？構えなんだった。そんなメディナ。そんな彼女の子だった。しかし、魔法は王国への旅をとうした。そして、自分の体を持っていた。ある日、交通事故によう、途中からダンジョンが出来るのか？……？そんなからもいい詰めます。  ある日、ある日本当然の駆除上げ、武器は戦力の教を、出る日々を癒さして、望みを求めだけら、そのなっていたのは、この世界の能力は破滅したの美女だがらします。だ。本編は完結していたのミーライフ！夢はごめにくれ合い、異世界に転生した。そこで真の目的な力である。それは、自分の体の世界にはます。そして、特別な国のだことが大きるの信吾に愛しても、その名前は無断島ノとなったり、ミーナルは全員が黒髪の騎士と
#
# Epoch 48/60
# 154101/154101 [==============================] - 132s 857us/step - loss: 1.6784
# エポック:  47
# シード:    山田健一は３５歳
#   山田健一は３５歳になったの、妹のメイ・・・サル・ス・ム・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・・
#
# Epoch 49/60
# 154101/154101 [==============================] - 137s 890us/step - loss: 1.6650
# エポック:  48
# シード:    山田健一は３５歳
#   山田健一は３５歳のサラリーマンだった。転生したらはこの世界に転生した私は、異世界で冒険者をしてしまった。より、西洋を救いた時により、Ｒ130万ＰＧブックウォーカーように生きてるんだからし、エルフの世界。それても自分の手によって、特別な世界で、光景勝と組だけのお熟足設定ねは、小説でするからにご指えます。途中、読んでもの応援かりにするように巻き込まれた。京之介ライムに旅を出したう。しかし、彼女の前の調べるほどの間だった。あるが、適だった。今度は当然のないにも、いたする。目の前に、これは、事故でチートを持つ、時代の力が夢の暗殺者はとして、前世の記憶を持つ、堅実の地下衆ロリアルフ。そして彼は魔王の学生を残ったり、人の記憶を持っていた。ありがとうございます。  前世の記憶を思い出す。これは、そんな家庭を生活して生き残っていく。そんなモノベルスに向き返ったり、原因で違ってレムが存在だった。ゲームの世界に転生していた。
#
# Epoch 50/60
# 154101/154101 [==============================] - 133s 865us/step - loss: 1.6502
# エポック:  49
# シード:    山田健一は３５歳
#   山田健一は３５歳のサラリーマンだった。そして彼女の子は元気により、文字を目指しております。  就職を卒業した彼は、周りの人生を歩ったり、割と一度は弱将しといった。だが、気づくたらいとんですかもうとなった。父さんていた。そんなの人生を送る日に、嫁に徹がダンは帝国の貴族じゃんだった。しかし、彼女は認められる。その領地を発展させられる。心を持つついた。それは、本来などとは違うな生。そういう事だ。異世界の生まれ変わった先は、生きの行く事になる、異世界へと転生したら、岩にある。それは、人間で使われた俺は、妹ものかまであった。そんな彼は元凶暴な魔法の存在になった。これ、それはそれままたらと思います。不屈者の光口を満喫し固定。した先は完結。後社畜生ましたのオンジをポイントラットン～12月20日発売中です。コミックス1巻重版決定しました。  ました。書籍化決定してします。完結しています！１０１０年超絶者達成り上がる。魔物
#
# Epoch 51/60
# 154101/154101 [==============================] - 138s 896us/step - loss: 1.6367
# エポック:  50
# シード:    山田健一は３５歳
#   山田健一は３５歳のサージは、仕事の方法を開きないてお話のは、おぜか中２００万PV達成長していく。された俺は、人間だけど、なくの気づくたら貴族の子に生まれたのは、やってなくのた主人公は、なりによってくおさえないう。それは、神様の元の世界では役立役にまた。外れれ、国は日本に囲まれなわっていく。そのできないな人間にはいただかった。だが、次に目が覚めたときて、誰にもられれない。そうなく、彼は、前世であるらず、異世界でいより、ツギクルを掲載中！
#
# Epoch 52/60
# 154101/154101 [==============================] - 136s 881us/step - loss: 1.6230
# エポック:  51
# シード:    山田健一は３５歳
#   山田健一は３５歳のサラリーマンだった。子だし周りに人たらした。現実ではなくことになってしまう。その時には、他の人間にを取り合っされて、前世の知識を使っていた。そんならず、幽霊やちりがいきるお話です。
#
# Epoch 53/60
# 154101/154101 [==============================] - 138s 892us/step - loss: 1.6111
# エポック:  52
# シード:    山田健一は３５歳
#   山田健一は３５歳の先生まれた元社畜の成り上がってみたい……、最強賢者。基本編第一章：竜１人のです。中ですの中二の書いたのですが、これは、何故かしか、ケントにしから始まる。だが、何でも良くれることになる。これは世界では残酷描写有り性別の評価値観光の始めた。憧れ、時間を過去候補不死になんて、まま困らしく虐のプロースキンと共によります。ファンタジー世界を超えて生にて、ゆっくり展開でする。中です！書籍化に伴いて蘇れ。これに、相変わらい回しました！  ふも気がつくとて送れることを決意する。これは、何故かしか、ケントにしから生まれたば、思如強さな人生が、賢者の続編でR二人の話もご覧いただろ、気づくというのは誰からもじめ出た。そうにもふれないというからにいかいた。だがあれば、高校からのから考えてやられるのか？？つかなろうとは思いながらないということを思い出す。これは、大慌くのままった。  日本では、前世で無双しまでも、
#
# Epoch 54/60
# 154101/154101 [==============================] - 134s 868us/step - loss: 1.5975
# エポック:  53
# シード:    山田健一は３５歳
#   山田健一は３５歳のサラリーマンだった。それで、心とふわさい。しました。ただが、念頭の日本では、魔法を使え、え切りのす人になっていた。そんな彼はそこに世界。そんな彼はそこにまでもごくなくないと思われるか腹黒い少年を人組ね、豚ャハーター。その武器は、突然としてもられたのは、やってその世界では珍しい黒い髪と黒い瞳の少年へと生を受けなれたい、ことを確信している予定でする、そんなチートスキルをもらいな能力を得たし、そのは既におりしく。しかしました。前世の記憶を思い出す。これは、そんな彼を取った程度に生き残ることを思い出す。これは、そんな彼を取った程度に生き残った人族だった。  神様のミスキル毒師なる。その知識となった学院で生活かったり、強制騎士サイして周りが兄たちかする物語。ある日々とロッド、世界に成り上がっていく。そして、日本人生を救う為に、何をしかもうとしているとしておりというの能力となんだ。そのできないとの子
#
# Epoch 55/60
# 154101/154101 [==============================] - 134s 872us/step - loss: 1.5851
# エポック:  54
# シード:    山田健一は３５歳
#   山田健一は３５歳かなりますのごいく……。そんなことはない。ころし、ニール版と聞かえてレベルトリア。次第二巻が発売されます  作画像とクース様から書籍化しております。  貴族の子男子と呼ばれる。魔法やポーコトとせって、若くすらぬ。としていくなることを決意する。  もありました。
#
# Epoch 56/60
# 154101/154101 [==============================] - 136s 883us/step - loss: 1.5730
# エポック:  55
# シード:    山田健一は３５歳
#   山田健一は３５歳のサラリーマンだった。子だったのだけ、それは、自分の体は、やらこそことが決定しました！？
#
# Epoch 57/60
# 154101/154101 [==============================] - 136s 879us/step - loss: 1.5618
# エポック:  56
# シード:    山田健一は３５歳
#   山田健一は３５歳かなりまで、シリーズ内で、書籍版も登場します。感想返信は諸ズ２３つ名にはＷｅｂ版と土衛が起かしれました。川の中世界を超えてした。恋愛いのであるとなります。日本し考えた。ある日、賭けワールドイフストハーメン  生まれたチートを持つなくベルスが、前世の記憶を思い出す。これは、そんな家庭にも賢者。技能もあった。トラゴー少女によっている事がある。そしておっさんだよって、週間に生まれるか。男が、そんな人生だった。そこで幸落が始ました。そんな彼が、そこでは、彼女は魔女のみたいだけど、ある日、穴は飛ばされていた。そんな彼の異世界で生のていたらばったの子だけどそして転生していた。前世の知識と魔法水住の息子行しました。サントラシス、“イシストーリンスだ。第二の人生です。剣と魔法のファンタジー世界でも、見ることが、生まれ変わった。だった主人公が、自称の最強のオレストーレン。たずに希望を望ぐら亡してオタジは、世
#
# Epoch 58/60
# 154101/154101 [==============================] - 135s 874us/step - loss: 1.5486
# エポック:  57
# シード:    山田健一は３５歳
#   山田健一は３５歳のサラリーマンだが、田中は、死んだ社畜生ますの世界であるグランフィーゼの遺跡上諸義法記憶えません。そのまで、ご了承ください。家門一剣士魔法の娘にあるれ、そんなの誰も無視され、120話で発売中です。一巻が発売中です。年７月10日本小国１巻発売中です。ぜひかりのターの為にスクーンとしています。完結したいます。  目の前めで死ぬのだった。どこから俺は死んだらし、しょうとこうから、彼女はないいだけのファンタジー世界の片隅で暮らしくれた件がついたらにはつます。て、時間を過ぎない森の中。アレストはなり異世界でもられ、そんな世界を司る女神からもそいからも収納可能力を使い、努力をしていく、語の物がように性やからチート能力を持ってくまため、一人の少女は出会った女、彼の忍法は炸裂！忍術が冴え渡り馬鹿にしてくる連中を始める。後に不安はなくていたと嬉しいです。精霊と感外に合流れる寸前の記憶といるのだった。脇役です
#
# Epoch 59/60
# 154101/154101 [==============================] - 135s 876us/step - loss: 1.5388
# エポック:  58
# シード:    山田健一は３５歳
#   山田健一は３５歳のサラリーマン能ないったらす。その思い出は、だったので、あったの子供に転生してしまったら、彼はモテスターは現世、貴族の長男となくて過酷な事活動物を105万能力段よりなくっていく。その世界に転生した前世の記憶がある。  目覚ますと、そこは大人生の旅することを身についた時に、たワールド・アステムと暖かなろうには無いずになるまだった。それは、俺はなく、それらも素人の常識者の物語は初投稿です。
#
# Epoch 60/60
# 154101/154101 [==============================] - 128s 827us/step - loss: 1.5274
# エポック:  59
# シード:    山田健一は３５歳
#   山田健一は３５歳のサラリーマンだった。馬をあるれずが居た。その思い出してはなんていく。ゲームのプチートスキルをかっています。その宿屋はバートをする。それは三十路が、軽度はスローロンティの王子。第二の人生を終了しました。高校一年の男にし、ヴェルデリアの少女にはたの能能力を与えられることになってはずれたの間だけど、恋愛いく薄めのために心人間の子になった。ある日、積みするも、ときかった主人公は、特術である、その世界を管理することを決意した。体が、回るは、魔法学使は、大士・オークが歩んだいことに諦めない。  動きますので書けていたも読んのからに働くさったり、魔王として、自分の居場所を作っていく！ 異世界転生した先は剣と魔法の世界へと転生したら異世界転生した。それは、大戦いも何を手にようございます。ご了承ください。  人生の、ぶ愛された雄二の人生を生きてしまった。誰かも三男とならにながらも、いずのは非正の文室の領地
